# %% [markdown]
# ---
# # Apresentação
# ---
# ## Resumo
# > Suponha uma empresa de turismo em uma grande cidade e que há um turista que deseja conhecer essa cidade. Entretanto, ele elencou apenas 1 ponto que deseja visitar. A proposta do projeto é desenvolver um algoritmo capaz de gerar uma rota a partir da sede da empresa e que passe por uma quantidade mínima de pontos turísticos, de modo que o ponto final seja o ponto escolhido pelo cliente. Assim, ele poderá conhecer mais lugares da cidade, além daquele previamente escolhido.
#
# ## Objetivo
# > O presente arquivo visa utilizar a API da Plataforma Google Maps para extrair os dados dos pontos turísticos, os quais serão utilizados para o desenvolvimento do projeto descrito.
#
# ## Notas
# > Este Código foi desenvolvido em Python no Google Colaboratory e seu funcionamento está a ele relacionado.
#
# > Acesse a [documentação completa](https://developers.google.com/maps/documentation/places/web-service?hl=pt-br) da API Places.
#
# > **Para um melhor acompanhamento**, [visualize através do Colab](https://colab.research.google.com/drive/1kC_7_iHB3_C8XIOqyBHwcpdKS0YokC5v?usp=sharing) utilizando os índices.

# %% [markdown]
# ---
# # Bibliotecas, funções e constantes
# ---

# %%
# @title Importando as bibliotecas necessárias

# API
import requests

# Matemática
import math
import numpy as np
import pandas as pd

# Manipulação
import json
from datetime import datetime
from binascii import Error
from time import sleep
from pprint import pprint

# %%
# @title Definindo a chave da API

API_KEY = '#'

# %%
# @title Função para obter a geocodificação de um ponto

def obtem_geocodificacao(endereco: str) -> tuple[float, float]:
  """
    Obtem a geocodificação (Latitude e Longitude) de um determinado endereço do
    Google maps, caso não seja possível, um Erro é lançado.
  """
  base_url = 'https://maps.googleapis.com/maps/api/geocode/json'

  params = {
      'key': API_KEY,
      'address': endereco,
      'language': 'pt-BR'
  }
  response = requests.post(base_url, params=params)
  resultado = response.json()

  if resultado['status'] == "OK":
    location = resultado['results'][0]['geometry']['location']
    lat, lng = float(location['lat']), float(location['lng'])
    return (lat, lng)

  else:
    raise Error(f'Erro na api do google maps: {resultado["error_message"]}')

# %%
# @title Função para obter a distância euclidiana entre dois pontos


def distancia_euclidiana_em_km(lat1: float, lon1: float , lat2: float , lon2: float ) -> float:
  """
    Calcula a distância euclidiana (aproximada em quilômetros) entre dois pontos geográficos, dados suas latitudes e longitudes
    Material de referência:
    https://cref.if.ufrgs.br/?contact-pergunta=calculo-aproximado-de-distancias-com-base-em-coordenadas-de-latitude-e-longitude
  """
  lat_km_per_degree = 111.1
  lon_km_per_degree = lat_km_per_degree * math.cos(math.radians((lat1 + lat2) / 2))
  delta_lat = (lat2 - lat1) * lat_km_per_degree
  delta_lon = (lon2 - lon1) * lon_km_per_degree
  distancia_euclidiana = math.sqrt(delta_lat**2 + delta_lon**2)
  return distancia_euclidiana

# %%
# @title Função para extrair pontos turisticos dentro de um determinado raio

def extrai_pontos_turisticos(lat: float, lng: float, raio: float, quantidade: int = 40) -> pd.DataFrame:
  """
    Extrai determinada quantidade de pontos turisticos dentro de um raio a partir de um ponto (latitude, longitude).

    Caso a quantidade não seja especificada, 40 pontos serão buscados por padrão.

    Caso haja algum erro com a API, um Erro é lançado.
  """
  base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

  params = {
      'location': f"{lat},{lng}",
      'radius': raio,
      'key': API_KEY,
      'language': 'pt-BR',
      'type': 'tourist_attraction'
  }

  pontos_turisticos = []

  while True:
    response = requests.post(base_url, params=params)
    resultados = response.json()

    if resultados['status'] != 'OK':
      raise Error(f'Erro na api do google maps: {resultados["error_message"]}')

    pontos_turisticos.extend(resultados['results'])

    if (len(pontos_turisticos) >= quantidade):
      break

    # Se há um token de próxima página na resposta, significa que há mais resultados disponíveis para busca
    if 'next_page_token' in resultados:
      next_token = resultados['next_page_token']
      params['pagetoken'] = next_token
      sleep(2)
    else:
      break

  return pontos_turisticos

# %%
# @title Função para obter a distância estimada entre todos os pontos - h(n)

def obtem_distancia_estimada_entre_todos_os_pontos(todos_os_pontos: pd.DataFrame) -> pd.DataFrame:
  """
    Obtem a distancia estimada de cada ponto para cada ponto turistico.

    Esta função utiliza a função de distância euclidiana aproximada para Km.

    Caso haja algum erro com a API, um Erro é lançado.
  """
  matriz_distancia_euclidiana_km = pd.DataFrame(index=df['Place ID'], columns=df['Place ID'])

  # Iterando sobre cada linha do dataFrame (cada ponto turístico)
  for i, linha_i in df.iterrows():
    for j, linha_j in df.iterrows():
      # Se os pontos turísticos forem diferentes, a distância entre eles é calculada e inserida na matriz
      if i != j:
          dist = distancia_euclidiana_em_km(linha_i['Latitude'], linha_i['Longitude'], linha_j['Latitude'], linha_j['Longitude'])
          matriz_distancia_euclidiana_km.at[linha_i['Place ID'], linha_j['Place ID']] = dist
      # Se os pontos forem os mesmos, a distância é definida como 0
      else:
          matriz_distancia_euclidiana_km.at[linha_i['Place ID'], linha_j['Place ID']] = 0

  return matriz_distancia_euclidiana_km

# %%
# @title Função para obter a distância real e tempo real entre todos os pontos - g(n)

def obtem_distancia_e_tempo_real_entre_todos_os_pontos(todos_os_pontos: pd.DataFrame, meio_de_transporte: str) -> tuple[pd.DataFrame, pd.DataFrame]:
  """
    Obtem a distancia e o tempo real gasto de cada ponto para cada ponto turistico.

    Essa função utilizada técnica de lotes respeitando o máximo de pontos permitidos por requisição da API (25 pontos).

    Caso haja algum erro com a API, um Erro é lançado.
  """
  base_url = "https://maps.googleapis.com/maps/api/distancematrix/json"

  # Criando uma nova coluna no dataFrame para facilitar o envio para a API
  todos_os_pontos['coord'] = todos_os_pontos['Latitude'].astype(str) + ',' + todos_os_pontos['Longitude'].astype(str)

  params = {
    'origins': None,
    'destinations': None,
    'mode': meio_de_transporte,
    'key': API_KEY,
    'language': 'pt-BR'
  }

  quantidade_total_de_pontos = len(todos_os_pontos)
  maximo_por_request = 25

  # Inicializando um dataFrame para armazenar a matriz de distância e tempo, com
  # os IDs dos pontos turísticos como índices e colunas
  matriz_distancia_por_carro = pd.DataFrame(index=todos_os_pontos['Place ID'], columns=todos_os_pontos['Place ID'])
  matriz_tempo_por_carro = pd.DataFrame(index=todos_os_pontos['Place ID'], columns=todos_os_pontos['Place ID'])

  for i, linha_i in todos_os_pontos.iterrows():
    # Agrupando os destinos em lotes, de acordo com o número máximo permitido por solicitação
    lotes_de_destinos = [
        todos_os_pontos['coord'].iloc[i:i + maximo_por_request].tolist()
        for i in range(0, quantidade_total_de_pontos, maximo_por_request)
    ]
    lotes_de_place_id = [
        todos_os_pontos['Place ID'].iloc[i:i + maximo_por_request].tolist()
        for i in range(0, quantidade_total_de_pontos, maximo_por_request)
    ]

    params['origins'] = linha_i['coord']
    for lote, lote_place_id in zip(lotes_de_destinos, lotes_de_place_id):
      params['destinations']  = '|'.join(lote) # Formatando destinos para a API

      response = requests.get(base_url, params=params)
      resultado = response.json()

      if resultado['status'] != 'OK':
        raise Error(f'Erro na api do google maps: {resultado["error_message"]}; Erro na linha {i} do lote {lote}')

      origem = resultado['origin_addresses'][0]
      for destino, resposta_api, place_id in zip(resultado['destination_addresses'], resultado['rows'][0]['elements'], lote_place_id):
          distancia = tempo = 0
          # Se a origem é igual ao destino, a distancia e tempo de viagem são 0
          # Senão, obtem a distancia e tempo, convertendo para quilômetros e horas, respectivamente
          if origem == destino:
              distancia = tempo = 0
          else:
              distancia_em_metros = resposta_api['distance']['value']
              tempo_em_segundos = resposta_api['duration']['value']

              distancia_em_km = float(distancia_em_metros) / 1000.0
              tempo_em_horas = float(tempo_em_segundos) / 3600.0

              distancia = distancia_em_km
              tempo = tempo_em_horas

          matriz_distancia_por_carro.at[linha_i['Place ID'], place_id] = distancia
          matriz_tempo_por_carro.at[linha_i['Place ID'], place_id] = tempo

  return matriz_distancia_por_carro, matriz_tempo_por_carro

# %% [markdown]
# ---
# # Extração de dados
# ---

# %%
# @title Definindo as Constantes

# Endereço da sede da empresa de turismo (ponto inicial)
SEDE_LOCALIZACAO = 'R. Barão de São Francisco, 236 - Vila Isabel, Rio de Janeiro - RJ'

# Latitude e Longitude da sede da empresa
LAT, LNG = obtem_geocodificacao(SEDE_LOCALIZACAO)

# Raio de distância da sede onde serão buscados pontos turísticos (em metros)
RAIO = 10000

QUANTIDADE_MAXIMA_DE_PONTOS = 40

# Cidade onde serão buscados os pontos turísticos
CIDADE = "rio"

# Modo de transporte utilizado para a rota
MODO_DE_TRANSPORTE = 'driving'

# %%
# @title Obtendo lista de pontos turísticos próximos à empresa
pontos_turisticos = extrai_pontos_turisticos(LAT, LNG, RAIO, QUANTIDADE_MAXIMA_DE_PONTOS)

# %%
# @title Exportando os dados obtidos
# Será gerado um DataFrame e um arquivo .csv (Excel)

# Preparando os dados para o DataFrame
pontos_turisticos_filtrado = [{
  'Name': ponto['name'],
  'Latitude': ponto['geometry']['location']['lat'],
  'Longitude': ponto['geometry']['location']['lng'],
  'Place ID': ponto['place_id'],
  'Rating': ponto['rating'],
  'User Ratings Total': ponto['user_ratings_total'],
  'Address': ponto['vicinity'],
  'Types': ', '.join(ponto['types'])
  } for ponto in pontos_turisticos if ponto['business_status'] == 'OPERATIONAL']

# Criando o DataFrame
df_pontos = pd.DataFrame(pontos_turisticos_filtrado)

# Incluindo ponto inicial
df_sede = pd.DataFrame([{
    'Name': 'Sede da empresa (Ponto inicial)',
    'Latitude': LAT,
    'Longitude': LNG,
    'Place ID': "ID_GERADO",
    'Rating': None,
    'User Ratings Total': None,
    'Address': SEDE_LOCALIZACAO,
    'Types': None
}])

df = pd.concat([df_sede, df_pontos], ignore_index=True)

# Salvando em um arquivo Excel
df.to_excel(f'pontos_turisticos-{CIDADE}.xlsx', index=False)

# %%
display(df.head())
# Out:
#                                     Name   Latitude  Longitude  \
# 0        Sede da empresa (Ponto inicial) -22.919327 -43.250186
# 1  Praça da República - Campo de Santana -22.906800 -43.188542
# 2                        Cristo Redentor -22.951916 -43.210487
# 3    Theatro Municipal do Rio de Janeiro -22.909048 -43.176558
# 4                               Maracanã -22.912161 -43.230171
#
#                       Place ID Rating User Ratings Total  \
# 0                    ID_GERADO   None               None
# 1  ChIJ-SApQ2l_mQARnALEEfr3Yy8    4.1              12094
# 2  ChIJP6FKmNV_mQAR3gKVAdeEyZ0    4.8             118621
# 3  ChIJUSQw7WF_mQARQKXFPmK9_6A    4.8              19776
# 4  ChIJDYuIul1-mQAR5XRi7ogx8_U    4.7             103327
#
#                                              Address  \
# 0  R. Barão de São Francisco, 236 - Vila Isabel, ...
# 1                             Centro, Rio de Janeiro
# 2  Parque Nacional da Tijuca - Alto da Boa Vista,...
# 3       Praça Floriano, S/N - Centro, Rio de Janeiro
# 4  Rua Professor Eurico Rabelo - Maracanã, Rio de...
#
#                                                Types
# 0                                               None
# 1  park, tourist_attraction, point_of_interest, e...
# 2  tourist_attraction, point_of_interest, establi...
# 3  tourist_attraction, point_of_interest, establi...
# 4  stadium, tourist_attraction, point_of_interest...

# %% [markdown]
# ---
# # Cálculo de distâncias e tempo de viagem entre os pontos turísticos
# ---

# %%
# @title Mapeando a distância estimada entre todos os pontos

matriz_distancia_euclidiana = obtem_distancia_estimada_entre_todos_os_pontos(todos_os_pontos=df)

display(matriz_distancia_euclidiana.head())
# Out:
# Place ID                    ID_GERADO ChIJ-SApQ2l_mQARnALEEfr3Yy8  \
# Place ID
# ID_GERADO                           0                    6.460012
# ChIJ-SApQ2l_mQARnALEEfr3Yy8  6.460012                           0
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0  5.441316                    5.492379
# ChIJUSQw7WF_mQARQKXFPmK9_6A  7.620683                    1.251597
# ChIJDYuIul1-mQAR5XRi7ogx8_U  2.197447                    4.301661
#
# Place ID                    ChIJP6FKmNV_mQAR3gKVAdeEyZ0  \
# Place ID
# ID_GERADO                                      5.441316
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    5.492379
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                           0
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    5.893671
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    4.854315
#
# Place ID                    ChIJUSQw7WF_mQARQKXFPmK9_6A  \
# Place ID
# ID_GERADO                                      7.620683
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    1.251597
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    5.893671
# ChIJUSQw7WF_mQARQKXFPmK9_6A                           0
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    5.497484
#
# Place ID                    ChIJDYuIul1-mQAR5XRi7ogx8_U  \
# Place ID
# ID_GERADO                                      2.197447
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    4.301661
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    4.854315
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    5.497484
# ChIJDYuIul1-mQAR5XRi7ogx8_U                           0
#
# Place ID                    ChIJf1woiGR_mQARyXRjaTaeIBc  \
# Place ID
# ID_GERADO                                      7.158725
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    1.021903
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    5.346846
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.560382
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    5.069491
#
# Place ID                    ChIJ0QTJyWF_mQAR4t3oNko2kQo  \
# Place ID
# ID_GERADO                                      7.715566
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    1.371128
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    5.899522
# ChIJUSQw7WF_mQARQKXFPmK9_6A                      0.1285
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    5.599689
#
# Place ID                    ChIJA0tgM6PVmwARYbqb7Eo9VO4  \
# Place ID
# ID_GERADO                                      6.312418
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    7.927838
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    2.454049
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    8.344533
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    6.520325
#
# Place ID                    ChIJaXW-F2R_mQARjtqcwUcZSfM  \
# Place ID
# ID_GERADO                                      7.167557
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.903684
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    5.498708
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.468073
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    5.057458
#
# Place ID                    ChIJXbKphbbVmwARkyFh0LoSTOY  ...  \
# Place ID                                                 ...
# ID_GERADO                                      6.822011  ...
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    8.973396  ...
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    3.518692  ...
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    9.411867  ...
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    7.303203  ...
#
# Place ID                    ChIJGx7BXoh-mQARK_B4SbrTjTI  \
# Place ID
# ID_GERADO                                      2.183044
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    5.381863
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    6.388135
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    6.628885
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    1.596858
#
# Place ID                    ChIJ0d1kUQp-mQARZ17Wa3A9NKc  \
# Place ID
# ID_GERADO                                      0.312916
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    6.569937
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                     5.74192
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    7.748787
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    2.275184
#
# Place ID                    ChIJfVzFqCPVmwARUBFlJIm6e8k  \
# Place ID
# ID_GERADO                                      9.949746
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                     9.28942
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    4.716227
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    9.156093
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    9.570452
#
# Place ID                    ChIJ6ZhYkbd9mQARJJ0N13gYnw4  \
# Place ID
# ID_GERADO                                      2.985584
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    8.528196
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                     8.42665
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    9.770977
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    4.418021
#
# Place ID                    ChIJabwOd29_mQARKGuNjNLqwuM  \
# Place ID
# ID_GERADO                                      6.729965
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.555099
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    5.268623
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.892054
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    4.615687
#
# Place ID                    ChIJIVr_4xB-mQARA3_foQEaiIA  \
# Place ID
# ID_GERADO                                      1.738835
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    5.849223
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    3.726442
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    6.865043
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    2.311281
#
# Place ID                    ChIJiS4yHPp-mQARAgzgz4kGrs8  \
# Place ID
# ID_GERADO                                      3.245864
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    3.454449
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    5.299569
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    4.694575
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    1.099097
#
# Place ID                    ChIJ3Vt-cOKBmQARV_PYv8SfH2A  \
# Place ID
# ID_GERADO                                      7.980361
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    1.559693
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    6.775119
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.967599
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    5.799669
#
# Place ID                    ChIJcSsrEEd8mQARzsVXC8nv8uk  \
# Place ID
# ID_GERADO                                      4.908613
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    9.163326
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                   10.204937
# ChIJUSQw7WF_mQARQKXFPmK9_6A                   10.406903
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    5.644091
#
# Place ID                    ChIJ4zqbyNV_mQAR_BSfApu9sEY
# Place ID
# ID_GERADO                                      5.094413
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                   10.836962
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    7.119472
# ChIJUSQw7WF_mQARQKXFPmK9_6A                   11.798324
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    7.053464
#
# [5 rows x 39 columns]

# %%
# @title Mapeando a distância e tempo real gasto entre os pontos

matriz_distancia_por_carro, matriz_tempo_por_carro = obtem_distancia_e_tempo_real_entre_todos_os_pontos(
    todos_os_pontos=df,
    meio_de_transporte=MODO_DE_TRANSPORTE
)

matriz_distancia_por_carro.to_excel(f'matriz_distancia_carro_km-{CIDADE}.xlsx')
matriz_tempo_por_carro.to_excel(f'matriz_tempo_carro_horas-{CIDADE}.xlsx')

# %%
matriz_distancia_por_carro.head()
# Out:
# Place ID                    ID_GERADO ChIJ-SApQ2l_mQARnALEEfr3Yy8  \
# Place ID
# ID_GERADO                           0                       7.393
# ChIJ-SApQ2l_mQARnALEEfr3Yy8     8.291                           0
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0     16.23                      12.627
# ChIJUSQw7WF_mQARQKXFPmK9_6A     9.611                       2.828
# ChIJDYuIul1-mQAR5XRi7ogx8_U     4.264                       4.896
#
# Place ID                    ChIJP6FKmNV_mQAR3gKVAdeEyZ0  \
# Place ID
# ID_GERADO                                        21.523
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                      13.848
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                           0
# ChIJUSQw7WF_mQARQKXFPmK9_6A                      12.581
# ChIJDYuIul1-mQAR5XRi7ogx8_U                      19.026
#
# Place ID                    ChIJUSQw7WF_mQARQKXFPmK9_6A  \
# Place ID
# ID_GERADO                                         9.569
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                       3.684
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      12.783
# ChIJUSQw7WF_mQARQKXFPmK9_6A                           0
# ChIJDYuIul1-mQAR5XRi7ogx8_U                       7.072
#
# Place ID                    ChIJDYuIul1-mQAR5XRi7ogx8_U  \
# Place ID
# ID_GERADO                                         2.682
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                       6.767
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      14.706
# ChIJUSQw7WF_mQARQKXFPmK9_6A                       8.087
# ChIJDYuIul1-mQAR5XRi7ogx8_U                           0
#
# Place ID                    ChIJf1woiGR_mQARyXRjaTaeIBc  \
# Place ID
# ID_GERADO                                         8.984
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                       3.099
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      12.575
# ChIJUSQw7WF_mQARQKXFPmK9_6A                       0.879
# ChIJDYuIul1-mQAR5XRi7ogx8_U                       6.487
#
# Place ID                    ChIJ0QTJyWF_mQAR4t3oNko2kQo  \
# Place ID
# ID_GERADO                                         9.359
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                       3.474
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      12.339
# ChIJUSQw7WF_mQARQKXFPmK9_6A                       0.802
# ChIJDYuIul1-mQAR5XRi7ogx8_U                       6.862
#
# Place ID                    ChIJA0tgM6PVmwARYbqb7Eo9VO4  \
# Place ID
# ID_GERADO                                        13.151
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                      11.703
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      11.958
# ChIJUSQw7WF_mQARQKXFPmK9_6A                      13.023
# ChIJDYuIul1-mQAR5XRi7ogx8_U                      10.654
#
# Place ID                    ChIJaXW-F2R_mQARjtqcwUcZSfM  \
# Place ID
# ID_GERADO                                         8.977
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                       3.092
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      12.339
# ChIJUSQw7WF_mQARQKXFPmK9_6A                        1.15
# ChIJDYuIul1-mQAR5XRi7ogx8_U                        6.48
#
# Place ID                    ChIJXbKphbbVmwARkyFh0LoSTOY  ...  \
# Place ID                                                 ...
# ID_GERADO                                        14.245  ...
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                      12.797  ...
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      13.052  ...
# ChIJUSQw7WF_mQARQKXFPmK9_6A                      14.117  ...
# ChIJDYuIul1-mQAR5XRi7ogx8_U                      11.748  ...
#
# Place ID                    ChIJGx7BXoh-mQARK_B4SbrTjTI  \
# Place ID
# ID_GERADO                                         4.803
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                       7.698
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      15.637
# ChIJUSQw7WF_mQARQKXFPmK9_6A                       9.018
# ChIJDYuIul1-mQAR5XRi7ogx8_U                        4.43
#
# Place ID                    ChIJ0d1kUQp-mQARZ17Wa3A9NKc  \
# Place ID
# ID_GERADO                                          0.58
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                       7.735
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      15.673
# ChIJUSQw7WF_mQARQKXFPmK9_6A                       9.055
# ChIJDYuIul1-mQAR5XRi7ogx8_U                       3.707
#
# Place ID                    ChIJfVzFqCPVmwARUBFlJIm6e8k  \
# Place ID
# ID_GERADO                                        16.768
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                      15.321
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      15.576
# ChIJUSQw7WF_mQARQKXFPmK9_6A                      12.201
# ChIJDYuIul1-mQAR5XRi7ogx8_U                      14.271
#
# Place ID                    ChIJ6ZhYkbd9mQARJJ0N13gYnw4  \
# Place ID
# ID_GERADO                                         3.949
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                      10.161
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                        18.1
# ChIJUSQw7WF_mQARQKXFPmK9_6A                      11.481
# ChIJDYuIul1-mQAR5XRi7ogx8_U                       6.893
#
# Place ID                    ChIJabwOd29_mQARKGuNjNLqwuM  \
# Place ID
# ID_GERADO                                         8.176
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                        2.38
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      11.725
# ChIJUSQw7WF_mQARQKXFPmK9_6A                       1.416
# ChIJDYuIul1-mQAR5XRi7ogx8_U                       5.679
#
# Place ID                    ChIJIVr_4xB-mQARA3_foQEaiIA  \
# Place ID
# ID_GERADO                                          3.46
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                       7.724
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      14.095
# ChIJUSQw7WF_mQARQKXFPmK9_6A                       9.044
# ChIJDYuIul1-mQAR5XRi7ogx8_U                       3.588
#
# Place ID                    ChIJiS4yHPp-mQARAgzgz4kGrs8  \
# Place ID
# ID_GERADO                                         4.897
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                       4.917
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      13.588
# ChIJUSQw7WF_mQARQKXFPmK9_6A                       6.237
# ChIJDYuIul1-mQAR5XRi7ogx8_U                         2.4
#
# Place ID                    ChIJ3Vt-cOKBmQARV_PYv8SfH2A  \
# Place ID
# ID_GERADO                                        14.049
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                        6.89
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      15.711
# ChIJUSQw7WF_mQARQKXFPmK9_6A                       4.345
# ChIJDYuIul1-mQAR5XRi7ogx8_U                      11.553
#
# Place ID                    ChIJcSsrEEd8mQARzsVXC8nv8uk  \
# Place ID
# ID_GERADO                                         6.751
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                      12.652
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      29.567
# ChIJUSQw7WF_mQARQKXFPmK9_6A                      13.972
# ChIJDYuIul1-mQAR5XRi7ogx8_U                       9.384
#
# Place ID                    ChIJ4zqbyNV_mQAR_BSfApu9sEY
# Place ID
# ID_GERADO                                        10.976
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                      15.481
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      12.555
# ChIJUSQw7WF_mQARQKXFPmK9_6A                      16.801
# ChIJDYuIul1-mQAR5XRi7ogx8_U                      11.344
#
# [5 rows x 39 columns]

# %%
matriz_tempo_por_carro.head()
# Out:
# Place ID                    ID_GERADO ChIJ-SApQ2l_mQARnALEEfr3Yy8  \
# Place ID
# ID_GERADO                           0                    0.250278
# ChIJ-SApQ2l_mQARnALEEfr3Yy8  0.296667                           0
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0  0.673056                    0.519722
# ChIJUSQw7WF_mQARQKXFPmK9_6A     0.365                    0.146389
# ChIJDYuIul1-mQAR5XRi7ogx8_U  0.198611                    0.146944
#
# Place ID                    ChIJP6FKmNV_mQAR3gKVAdeEyZ0  \
# Place ID
# ID_GERADO                                      0.620833
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                       0.515
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                           0
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.553333
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.517778
#
# Place ID                    ChIJUSQw7WF_mQARQKXFPmK9_6A  \
# Place ID
# ID_GERADO                                      0.367778
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.195556
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.583611
# ChIJUSQw7WF_mQARQKXFPmK9_6A                           0
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.264722
#
# Place ID                    ChIJDYuIul1-mQAR5XRi7ogx8_U  \
# Place ID
# ID_GERADO                                      0.123333
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                       0.195
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.571389
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.263611
# ChIJDYuIul1-mQAR5XRi7ogx8_U                           0
#
# Place ID                    ChIJf1woiGR_mQARyXRjaTaeIBc  \
# Place ID
# ID_GERADO                                        0.3225
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                        0.15
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.555278
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.060833
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.219167
#
# Place ID                    ChIJ0QTJyWF_mQAR4t3oNko2kQo  \
# Place ID
# ID_GERADO                                      0.374167
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.201667
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.571944
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.066111
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.270833
#
# Place ID                    ChIJA0tgM6PVmwARYbqb7Eo9VO4  \
# Place ID
# ID_GERADO                                      0.356667
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                         0.3
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.425833
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.368611
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.253333
#
# Place ID                    ChIJaXW-F2R_mQARjtqcwUcZSfM  \
# Place ID
# ID_GERADO                                      0.323333
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.150833
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.564167
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.081111
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.220278
#
# Place ID                    ChIJXbKphbbVmwARkyFh0LoSTOY  ...  \
# Place ID                                                 ...
# ID_GERADO                                      0.408333  ...
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.351667  ...
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.477778  ...
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.420278  ...
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.305278  ...
#
# Place ID                    ChIJGx7BXoh-mQARK_B4SbrTjTI  \
# Place ID
# ID_GERADO                                      0.156389
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.215278
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.591667
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.283889
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.125556
#
# Place ID                    ChIJ0d1kUQp-mQARZ17Wa3A9NKc  \
# Place ID
# ID_GERADO                                      0.041389
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.266944
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.643333
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.335556
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.168889
#
# Place ID                    ChIJfVzFqCPVmwARUBFlJIm6e8k  \
# Place ID
# ID_GERADO                                      0.481667
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                       0.425
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.550833
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.413611
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.378611
#
# Place ID                    ChIJ6ZhYkbd9mQARJJ0N13gYnw4  \
# Place ID
# ID_GERADO                                      0.162222
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.299722
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.676111
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.368333
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.209722
#
# Place ID                    ChIJabwOd29_mQARKGuNjNLqwuM  \
# Place ID
# ID_GERADO                                      0.334722
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                      0.1575
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.535278
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.103889
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.231667
#
# Place ID                    ChIJIVr_4xB-mQARA3_foQEaiIA  \
# Place ID
# ID_GERADO                                      0.187778
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.299444
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.649722
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.368056
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.181667
#
# Place ID                    ChIJiS4yHPp-mQARAgzgz4kGrs8  \
# Place ID
# ID_GERADO                                      0.211389
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.187222
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                      0.5725
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.255833
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.108333
#
# Place ID                    ChIJ3Vt-cOKBmQARV_PYv8SfH2A  \
# Place ID
# ID_GERADO                                      0.382778
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.236389
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.571389
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.130278
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.279722
#
# Place ID                    ChIJcSsrEEd8mQARzsVXC8nv8uk  \
# Place ID
# ID_GERADO                                      0.211667
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                    0.381944
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.701111
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.450556
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.291944
#
# Place ID                    ChIJ4zqbyNV_mQAR_BSfApu9sEY
# Place ID
# ID_GERADO                                      0.480833
# ChIJ-SApQ2l_mQARnALEEfr3Yy8                        0.61
# ChIJP6FKmNV_mQAR3gKVAdeEyZ0                    0.666944
# ChIJUSQw7WF_mQARQKXFPmK9_6A                    0.678611
# ChIJDYuIul1-mQAR5XRi7ogx8_U                    0.492222
#
# [5 rows x 39 columns]

# %% [markdown]
# ---
# # Representação do Grafo e Hiperconexão
# ---

# %%
import folium
import pandas as pd

# %%
# @title Lendo Dataset
df_pontos = pd.read_excel('./pontos_turisticos-rio.xlsx')

df_distancias = pd.read_excel('./matriz_distancia_carro_km-rio.xlsx', index_col='Place ID')

# %%
# @title Função para criar um mapa com marcadores para todos os pontos turístico

def cria_mapa_com_pontos(todos_os_pontos: pd.DataFrame, com_raio=True):
  mapa = folium.Map(location=[df_pontos['Latitude'].mean(), df_pontos['Longitude'].mean()], zoom_start=12)

  for index, row in df_pontos.iterrows():
    if row['Name'] == 'Sede da empresa (Ponto inicial)':
      folium.Marker(
          [row['Latitude'], row['Longitude']],
          popup=row['Name'],
          icon=folium.Icon(color='green',icon_color='#F7F7F7', prefix='fa', icon='building')
      ).add_to(mapa)

      if com_raio:
        # Adiciona um círculo de 10 km de raio ao redor da sede
        folium.Circle(
            radius=10000,  # Raio em metros
            location=[row['Latitude'], row['Longitude']],
            popup='Área de 10 km',
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.1
        ).add_to(mapa)
    else:
      folium.Marker(
          [row['Latitude'], row['Longitude']],
          popup=row['Name'],
          icon=folium.Icon(color='red', prefix='fa', icon='camera')
      ).add_to(mapa)

  return mapa

mapa = cria_mapa_com_pontos(df_pontos)
mapa.save("representacao_problema_de_busca.html")
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4d46733ebca9571efcbacb6367b88e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4d46733ebca9571efcbacb6367b88e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4d46733ebca9571efcbacb6367b88e9 = L.map(
#                 &quot;map_e4d46733ebca9571efcbacb6367b88e9&quot;,
#                 {
#                     center: [-22.91904307435897, -43.20912784358975],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4efbb568f550ce48fa815132d09bfedc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e4d46733ebca9571efcbacb6367b88e9);
#
#
#             var marker_206d627daddc9361d7585e72e32aa962 = L.marker(
#                 [-22.9193268, -43.2501861],
#                 {}
#             ).addTo(map_e4d46733ebca9571efcbacb6367b88e9);
#
#
#             var icon_9eee44428d33430752ef8be2f47c8d2b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;#F7F7F7&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_206d627daddc9361d7585e72e32aa962.setIcon(icon_9eee44428d33430752ef8be2f47c8d2b);
#
#
#         var popup_0ee2345ffcf1b72e50fad5ac47d4de6c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d0df08ecbedb251ee1bca43449d38b9 = $(`&lt;div id=&quot;html_4d0df08ecbedb251ee1bca43449d38b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sede da empresa (Ponto inicial)&lt;/div&gt;`)[0];
#                 popup_0ee2345ffcf1b72e50fad5ac47d4de6c.setContent(html_4d0df08ecbedb251ee1bca43449d38b9);
#
#
#
#         marker_206d627daddc9361d7585e72e32aa962.bindPopup(popup_0ee2345ffcf1b72e50fad5ac47d4de6c)
#         ;
#
#
#
#
#             var circle_ba3f37a11bdac37d4ebcc2f520808909 = L.circle(
#                 [-22.9193268, -43.2501861],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e4d46733ebca9571efcbacb6367b88e9);
#
#
#         var popup_875addfcc4b35925f037fe855067640d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_944faf67dae282ad202930e6306cc49d = $(`&lt;div id=&quot;html_944faf67dae282ad202930e6306cc49d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Área de 10 km&lt;/div&gt;`)[0];
#                 popup_875addfcc4b35925f037fe855067640d.setContent(html_944faf67dae282ad202930e6306cc49d);
#
#
#
#         circle_ba3f37a11bdac37d4ebcc2f520808909.bindPopup(popup_875addfcc4b35925f037fe855067640d)
#         ;
#
#
#
#
#             var marker_6b6cdb5d6b6a2fcf01fd8a847f13debe = L.marker(
#                 [-22.9068001, -43.1885416],
#                 {}
#             ).addTo(map_e4d46733ebca9571efcbacb6367b88e9);
#
#
#             var icon_c1be3e155c7ed3165814fdff73ff1d5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6b6cdb5d6b6a2fcf01fd8a847f13debe.setIcon(icon_c1be3e155c7ed3165814fdff73ff1d5c);
#
#
#         var popup_f8ddbe861115e81472b3752a75ab564f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_71fb50d1238cde97897538b84a3d4f7d = $(`&lt;div id=&quot;html_71fb50d1238cde97897538b84a3d4f7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Praça da República - Campo de Santana&lt;/div&gt;`)[0];
#                 popup_f8ddbe861115e81472b3752a75ab564f.setContent(html_71fb50d1238cde97897538b84a3d4f7d);
#
#
#
#         marker_6b6cdb5d6b6a2fcf01fd8a847f13debe.bindPopup(popup_f8ddbe861115e81472b3752a75ab564f)
#         ;
#
#
#
#
#             var marker_ea200b7cbd987694e93f86026f8d3379 = L.marker(
#                 [-22.951916, -43.2104872],
#                 {}
#             ).addTo(map_e4d46733ebca9571efcbacb6367b88e9);
#
#
#             var icon_9385154a5698eecb454d592e77d757d7 = L.AwesomeMarkers.icon(
#                 {&quot;ext

# %%
# @title Função para criar conexoes em um mapa com marcadores

def adiciona_conexoes_em_um_mapa_com_pontos(mapa, grafo, densidade_linha=1):
  for place_id, grafo_ids in grafo.items():
      ponto_origem = df_pontos.loc[df_pontos['Place ID'] == place_id, ['Latitude', 'Longitude']].values[0]
      for conexao_id in grafo_ids:
          ponto_destino = df_pontos.loc[df_pontos['Place ID'] == conexao_id, ['Latitude', 'Longitude']].values[0]
          folium.PolyLine(
              locations=[ponto_origem, ponto_destino],
              color="blue",
              weight=densidade_linha
          ).add_to(mapa)

# %%
# @title Representando Hiperconectividade

mapa = cria_mapa_com_pontos(todos_os_pontos=df_pontos)

# Conectando cada ponto com todos os outros pontos
coords = df_pontos[['Latitude', 'Longitude']].values
for i in range(len(coords)):
  for j in range(len(coords)):
    if i != j:
      folium.PolyLine(
          locations=[coords[i], coords[j]],
          color="blue",
          weight=1,
          opacity=0.25
      ).add_to(mapa)

mapa.save("grafo_com_hiper-conectividade.html")
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e402c2f8981db03621aa7cfa9cab928 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e402c2f8981db03621aa7cfa9cab928&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e402c2f8981db03621aa7cfa9cab928 = L.map(
#                 &quot;map_3e402c2f8981db03621aa7cfa9cab928&quot;,
#                 {
#                     center: [-22.91904307435897, -43.20912784358975],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e99a92ec5268ca914fa035815cc8d97f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3e402c2f8981db03621aa7cfa9cab928);
#
#
#             var marker_308f31e220ed06d02eb52680380df828 = L.marker(
#                 [-22.9193268, -43.2501861],
#                 {}
#             ).addTo(map_3e402c2f8981db03621aa7cfa9cab928);
#
#
#             var icon_1a52ce7d77398cdacc963b276b036b3a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;#F7F7F7&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_308f31e220ed06d02eb52680380df828.setIcon(icon_1a52ce7d77398cdacc963b276b036b3a);
#
#
#         var popup_7680d73e70f45b6fa595e4bbe491eb72 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c8cbce93105ebd1ead54715a4e864af = $(`&lt;div id=&quot;html_2c8cbce93105ebd1ead54715a4e864af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sede da empresa (Ponto inicial)&lt;/div&gt;`)[0];
#                 popup_7680d73e70f45b6fa595e4bbe491eb72.setContent(html_2c8cbce93105ebd1ead54715a4e864af);
#
#
#
#         marker_308f31e220ed06d02eb52680380df828.bindPopup(popup_7680d73e70f45b6fa595e4bbe491eb72)
#         ;
#
#
#
#
#             var circle_2c3f7b141b08421e9bcdc7bac138c2c1 = L.circle(
#                 [-22.9193268, -43.2501861],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e402c2f8981db03621aa7cfa9cab928);
#
#
#         var popup_b67cb300686d2953ed74db4b7d26c5e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b66acb35ebc2091574a31f17cc7cb02 = $(`&lt;div id=&quot;html_6b66acb35ebc2091574a31f17cc7cb02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Área de 10 km&lt;/div&gt;`)[0];
#                 popup_b67cb300686d2953ed74db4b7d26c5e3.setContent(html_6b66acb35ebc2091574a31f17cc7cb02);
#
#
#
#         circle_2c3f7b141b08421e9bcdc7bac138c2c1.bindPopup(popup_b67cb300686d2953ed74db4b7d26c5e3)
#         ;
#
#
#
#
#             var marker_4d8a7ef60b3f6a932eb40c3fbec3cf9e = L.marker(
#                 [-22.9068001, -43.1885416],
#                 {}
#             ).addTo(map_3e402c2f8981db03621aa7cfa9cab928);
#
#
#             var icon_f7a242ffd0410ce71bb6ed1a971cc892 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4d8a7ef60b3f6a932eb40c3fbec3cf9e.setIcon(icon_f7a242ffd0410ce71bb6ed1a971cc892);
#
#
#         var popup_043fe15b607a4d282ad76d60e21add07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f39649639afad0bf901547a03d676bd9 = $(`&lt;div id=&quot;html_f39649639afad0bf901547a03d676bd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Praça da República - Campo de Santana&lt;/div&gt;`)[0];
#                 popup_043fe15b607a4d282ad76d60e21add07.setContent(html_f39649639afad0bf901547a03d676bd9);
#
#
#
#         marker_4d8a7ef60b3f6a932eb40c3fbec3cf9e.bindPopup(popup_043fe15b607a4d282ad76d60e21add07)
#         ;
#
#
#
#
#             var marker_9a27926c400b95931b6ee281dc91b670 = L.marker(
#                 [-22.951916, -43.2104872],
#                 {}
#             ).addTo(map_3e402c2f8981db03621aa7cfa9cab928);
#
#
#             var icon_adf40f8456d42b3133b37959dbb7ac92 = L.AwesomeMarkers.icon(
#                 {&quot;ext

# %%
# @title Constantes e Funções preliminares

NUMERO_MAXIMO_DE_CONEXOES = 5

def excede_limite(place_id):
  return len(conexoes[place_id]) >= NUMERO_MAXIMO_DE_CONEXOES

def existe_conexao(place_id, proximo_id):
  return place_id in conexoes[proximo_id]

def pode_conectar(place_id, proximo_id):
  return (
    proximo_id != place_id and
    not excede_limite(place_id) and
    not excede_limite(proximo_id) and
    not existe_conexao(place_id, proximo_id) and
    not existe_conexao(proximo_id, place_id)
  )

# %%
# @title Tentando Reduzir a Hiperconectividade criando 5 conexoes (mais proximos) para cada ponto
conexoes = {place_id: [] for place_id in df_distancias.index}

# Conecta cada ponto aos seus três pontos mais próximos que não excedam o limite de conexões
for place_id in df_distancias.index:
    distancias_ordenadas = df_distancias.loc[place_id].sort_values()
    for proximo_id in distancias_ordenadas.index:
        if pode_conectar(place_id, proximo_id):
            conexoes[place_id].append(proximo_id)
            conexoes[proximo_id].append(place_id)

            if excede_limite(place_id):
                break

mapa = cria_mapa_com_pontos(todos_os_pontos=df_pontos, com_raio=False)
adiciona_conexoes_em_um_mapa_com_pontos(mapa, conexoes, 2)
mapa.save("grafo_sem_hiper-conectividade_1.html")
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb6044b086dc46e8ad6814fe42210f3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb6044b086dc46e8ad6814fe42210f3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb6044b086dc46e8ad6814fe42210f3d = L.map(
#                 &quot;map_eb6044b086dc46e8ad6814fe42210f3d&quot;,
#                 {
#                     center: [-22.91904307435897, -43.20912784358975],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_97ac119def77b5af949a5cce42e1b9b2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eb6044b086dc46e8ad6814fe42210f3d);
#
#
#             var marker_af5464f6cd881fc32d73a0df885837f2 = L.marker(
#                 [-22.9193268, -43.2501861],
#                 {}
#             ).addTo(map_eb6044b086dc46e8ad6814fe42210f3d);
#
#
#             var icon_d9a6d3bcb4a74f47e8275ff3e8b65792 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;#F7F7F7&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_af5464f6cd881fc32d73a0df885837f2.setIcon(icon_d9a6d3bcb4a74f47e8275ff3e8b65792);
#
#
#         var popup_a4ae8408cf482fd3db7a18943006baea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_15e5607af377809974c4ab38aa67e6eb = $(`&lt;div id=&quot;html_15e5607af377809974c4ab38aa67e6eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sede da empresa (Ponto inicial)&lt;/div&gt;`)[0];
#                 popup_a4ae8408cf482fd3db7a18943006baea.setContent(html_15e5607af377809974c4ab38aa67e6eb);
#
#
#
#         marker_af5464f6cd881fc32d73a0df885837f2.bindPopup(popup_a4ae8408cf482fd3db7a18943006baea)
#         ;
#
#
#
#
#             var marker_abfe3a98945b103166480392d7b49b33 = L.marker(
#                 [-22.9068001, -43.1885416],
#                 {}
#             ).addTo(map_eb6044b086dc46e8ad6814fe42210f3d);
#
#
#             var icon_6148a88b8ad8f9b271e53b398ac46bde = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_abfe3a98945b103166480392d7b49b33.setIcon(icon_6148a88b8ad8f9b271e53b398ac46bde);
#
#
#         var popup_9d14acc5d041de7d084b9804950e19ef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce30ae978f622074df563831738c5885 = $(`&lt;div id=&quot;html_ce30ae978f622074df563831738c5885&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Praça da República - Campo de Santana&lt;/div&gt;`)[0];
#                 popup_9d14acc5d041de7d084b9804950e19ef.setContent(html_ce30ae978f622074df563831738c5885);
#
#
#
#         marker_abfe3a98945b103166480392d7b49b33.bindPopup(popup_9d14acc5d041de7d084b9804950e19ef)
#         ;
#
#
#
#
#             var marker_b02a74bd4d29198b2d2855d6f59487ac = L.marker(
#                 [-22.951916, -43.2104872],
#                 {}
#             ).addTo(map_eb6044b086dc46e8ad6814fe42210f3d);
#
#
#             var icon_ab673017fe359739d41822c397a53176 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b02a74bd4d29198b2d2855d6f59487ac.setIcon(icon_ab673017fe359739d41822c397a53176);
#
#
#         var popup_a98bd046c53a7ded0e2b364764e402f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2ce9da5418993a47e22fd757c3339fb = $(`&lt;div id=&quot;html_d2ce9da5418993a47e22fd757c3339fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cristo Redentor&lt;/div&gt;`)[0];
#                 popup_a98bd046c53a7ded0e2b364764e402f4.setContent(html_d2ce9da5418993a47e22fd757c3339fb);
#
#
#
#         marker_b02a74bd4d29198b2d2855d6f59487ac.bindPopup(popup_a98bd046c53a7ded0e2b364764e402f4)
#         ;
#
#
#
#
#             var marker_622e3da6e66d276b57e1637466fe57a2 = L.marker(
#                 [-22.9090481, -43.17655750000001],
#                 {}
#             ).addTo(map_eb6044b086dc46e8ad6814fe42210f3d);
#
#
#             var icon_04b273ff29fa357f23483325027ba15d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&q

# %%
# @title Tentando Reduzir a Hiper-conectividade criando 5 conexoes (mais proximos) para cada ponto partindo da sede
from collections import deque

conexoes = {place_id: [] for place_id in df_distancias.index}

fila = deque(["ID_GERADO"])
visited = []

while fila:
    place_id = fila.popleft()
    distancias_ordenadas = df_distancias.loc[place_id].sort_values().index
    visited.append(place_id)
    for proximo_id in distancias_ordenadas:  # Considerar apenas os mais próximos
        if proximo_id not in visited:
            conexoes[place_id].append(proximo_id)
            conexoes[proximo_id].append(place_id)
            fila.append(proximo_id)  # Adiciona o próximo ponto à fila para ser explorado

            if excede_limite(place_id):
              break

mapa = cria_mapa_com_pontos(todos_os_pontos=df_pontos, com_raio=False)
adiciona_conexoes_em_um_mapa_com_pontos(mapa, conexoes, 2)
mapa.save("grafo_sem_hiper-conectividade_2.html")
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80d4fdc79bd416f32a0e1b24b64478e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80d4fdc79bd416f32a0e1b24b64478e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80d4fdc79bd416f32a0e1b24b64478e9 = L.map(
#                 &quot;map_80d4fdc79bd416f32a0e1b24b64478e9&quot;,
#                 {
#                     center: [-22.91904307435897, -43.20912784358975],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12c22b2e65d0489237c8ca707952cadd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_80d4fdc79bd416f32a0e1b24b64478e9);
#
#
#             var marker_273103da1efac42f027cb02f9a79ae3f = L.marker(
#                 [-22.9193268, -43.2501861],
#                 {}
#             ).addTo(map_80d4fdc79bd416f32a0e1b24b64478e9);
#
#
#             var icon_0922641745a6fbae4c5db5a8759dbebe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;#F7F7F7&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_273103da1efac42f027cb02f9a79ae3f.setIcon(icon_0922641745a6fbae4c5db5a8759dbebe);
#
#
#         var popup_b0a87d048b5bfc90d14aa4cbbf18c96b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e07daccde17961459c68d390770f15ce = $(`&lt;div id=&quot;html_e07daccde17961459c68d390770f15ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sede da empresa (Ponto inicial)&lt;/div&gt;`)[0];
#                 popup_b0a87d048b5bfc90d14aa4cbbf18c96b.setContent(html_e07daccde17961459c68d390770f15ce);
#
#
#
#         marker_273103da1efac42f027cb02f9a79ae3f.bindPopup(popup_b0a87d048b5bfc90d14aa4cbbf18c96b)
#         ;
#
#
#
#
#             var marker_d78e1b25bc0fa9b9954ba6c914b8f10a = L.marker(
#                 [-22.9068001, -43.1885416],
#                 {}
#             ).addTo(map_80d4fdc79bd416f32a0e1b24b64478e9);
#
#
#             var icon_341f71fa76ebaffc555cbebd527194c1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d78e1b25bc0fa9b9954ba6c914b8f10a.setIcon(icon_341f71fa76ebaffc555cbebd527194c1);
#
#
#         var popup_17d324da122006c6ee772eb537ae2e63 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d4d6da066893de8d868491c428b4afa = $(`&lt;div id=&quot;html_5d4d6da066893de8d868491c428b4afa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Praça da República - Campo de Santana&lt;/div&gt;`)[0];
#                 popup_17d324da122006c6ee772eb537ae2e63.setContent(html_5d4d6da066893de8d868491c428b4afa);
#
#
#
#         marker_d78e1b25bc0fa9b9954ba6c914b8f10a.bindPopup(popup_17d324da122006c6ee772eb537ae2e63)
#         ;
#
#
#
#
#             var marker_644d902915cc17760bc1f94377743ef4 = L.marker(
#                 [-22.951916, -43.2104872],
#                 {}
#             ).addTo(map_80d4fdc79bd416f32a0e1b24b64478e9);
#
#
#             var icon_48e562a768b9d05a3ea05dbe6d5e00be = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_644d902915cc17760bc1f94377743ef4.setIcon(icon_48e562a768b9d05a3ea05dbe6d5e00be);
#
#
#         var popup_955dc0f28b56ad2aaba99975efff4f45 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b69a3ce625cc698e5b077a9dea42cfd1 = $(`&lt;div id=&quot;html_b69a3ce625cc698e5b077a9dea42cfd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cristo Redentor&lt;/div&gt;`)[0];
#                 popup_955dc0f28b56ad2aaba99975efff4f45.setContent(html_b69a3ce625cc698e5b077a9dea42cfd1);
#
#
#
#         marker_644d902915cc17760bc1f94377743ef4.bindPopup(popup_955dc0f28b56ad2aaba99975efff4f45)
#         ;
#
#
#
#
#             var marker_5f3709559617472bdd0d9aa34a2aa663 = L.marker(
#                 [-22.9090481, -43.17655750000001],
#                 {}
#             ).addTo(map_80d4fdc79bd416f32a0e1b24b64478e9);
#
#
#             var icon_cbfe0dd65ae247070b2c530bb420c6a0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&q
